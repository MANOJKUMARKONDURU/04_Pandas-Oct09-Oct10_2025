# %% [markdown]
# <a href="https://colab.research.google.com/github/MANOJKUMARKONDURU/04_Pandas-Oct09-Oct10_2025/blob/main/01_Padas%20Basics_Oct09/02_Pandas_getting_started.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
mydataset = {
    'cars' : ["Mustang", "Lambo", "Pagani"],
    'passings' : [3, 7, 2]
}

myvar = pd.DataFrame(mydataset)
print(myvar)
# Out:
#       cars  passings
# 0  Mustang         3
# 1    Lambo         7
# 2   Pagani         2

# %% [markdown]
# #Checking pandas version
#
# print(pd._ _ version _ _)
