# %% [markdown]
# <a href="https://colab.research.google.com/github/MANOJKUMARKONDURU/04_Pandas-Oct09-Oct10_2025/blob/main/02_Pandas-Cleaning%20Data%20-%20oct10_2025/01_Cleaning_Data_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Data Cleaning
# Means fixing bad data in the data set.
#
# Bad data could be:
# *  Empty cells
# *  Data in wrong format
# *  Wrong data
# *  Duplicates
